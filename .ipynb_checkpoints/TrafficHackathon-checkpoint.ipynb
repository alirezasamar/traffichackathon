# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import geocoder
import requests
import arrow
import math
import ratelim
from datetime import datetime
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-118-af4013215f17> in <module>()
#       2 import numpy as np
#       3 from pandas import DataFrame
# ----> 4 import geocoder
#       5 import requests
#       6 import arrow
#
# ModuleNotFoundError: No module named 'geocoder'

# %%
friday_data = pd.read_csv("week_2016-02-08/summarized_fri.csv")
friday_data.head(100)
# Out:
#       segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 0    68082212617       38        54.0        35.0         NaN         NaN
# 1    72175853321       39         NaN         NaN         NaN         NaN
# 2    35500859145       30         NaN         NaN         NaN         NaN
# 3   290178745056       46        46.0        24.0        44.0        47.0
# 4    30165704457       37         NaN         NaN         NaN         NaN
# 5   284843590368       35         NaN         NaN         NaN         NaN
# 6   235887927049       74        76.0        53.0         NaN         NaN
# 7    93550026505       53         NaN         NaN         NaN         NaN
# 8   203876998921       39        34.0         NaN         NaN         NaN
# 9   279508435680       53        54.0        79.0        72.0        68.0
# 10  118514523913       57        57.0         NaN        58.0        61.0
# 11  102509059849       42         NaN         NaN         NaN         NaN
# ...

# %%
friday_data.shape
# Out:
# (7038, 26)

# %%
friday_data["segment_id"].isnull().sum
friday_data["segment_id"].value_counts().index
# Out:
# Int64Index([ 61841088265, 233471754976, 103414776544, 223036579593,
#             108817040096, 283434304224, 316351202016, 209044381449,
#             241122165472, 298701570784,
#             ...
#             264006288096,  88516608736, 305311793888, 111031885577,
#              45198089993,  69189255904, 231290969865, 231022281440,
#             128480190217, 330779607776],
#            dtype='int64', length=7038)

# %%
friday_data["day_avg"].dtype
# Out:
# dtype('int64')

# %%
friday_data.count(axis=0)
# Out:
# segment_id     7038
# day_avg        7038
# hour_0_avg     3711
# hour_1_avg     2235
# hour_2_avg     1900
# hour_3_avg     1565
# hour_4_avg     1443
# hour_5_avg     1735
# hour_6_avg     2445
# hour_7_avg     3348
# hour_8_avg     4147
# hour_9_avg     4649
# hour_10_avg    4700
# hour_11_avg    4682
# hour_12_avg    4568
# hour_13_avg    4219
# hour_14_avg    4246
# hour_15_avg    4622
# hour_16_avg    4606
# hour_17_avg    4500
# hour_18_avg    4359
# hour_19_avg    4219
# hour_20_avg    4349
# hour_21_avg    4353
# hour_22_avg    4145
# hour_23_avg    3800
# dtype: int64

# %%
friday_data["day_avg"].isnull().sum
# Out:
# <bound method Series.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 7008    False
# 7009    False
# 7010    False
# 7011    False
# 7012    False
# 7013    False
# 7014    False
# 7015    False
# 7016    False
# 7017    False
# 7018    False
# 7019    False
# 7020    False
# 7021    False
# 7022    False
# 7023    False
# 7024    False
# 7025    False
# 7026    False
# 7027    False
# 7028    False
# 7029    False
# 7030    False
# 7031    False
# 7032    False
# 7033    False
# 7034    False
# 7035    False
# 7036    False
# ...

# %%
friday_data["day_avg"].value_counts().index
# Out:
# Int64Index([ 42,  40,  37,  38,  35,  48,  47,  33,  41,  32,
#             ...
#             104, 123, 101,   5, 216, 140, 124, 120, 112, 105],
#            dtype='int64', length=117)

# %%
plt.hist(friday_data["day_avg"].astype(float), bins = 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-afe495ce0593> in <module>()
# ----> 1 plt.hist(friday_data["day_avg"].astype(float), bins = 100)
#
# NameError: name 'plt' is not defined

# %%
import plotly.plotly as py 
import matplotlib.mlab as mlab


fig = plt.figure()

mu = friday_data["day_avg"].mean()
sigma = friday_data["day_avg"].std()
x = friday_data["day_avg"]

n, bins, patches = plt.hist(x, 50, normed=1, facecolor='blue', alpha=0.25)
y = mlab.normpdf(bins, mu, sigma)
plt.plot(bins, y, 'r--')
plt.xlabel('Avg Speed (km/h)')
plt.ylabel('Hours of a day')
plt.axis([0, 160, 0, 0.024])

plt.grid(True)

plt.subplots_adjust(left=0.15)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-101-c0e9718e5b00> in <module>()
# ----> 1 import plotly.plotly as py
#       2 import matplotlib.mlab as mlab
#       3
#       4
#       5 fig = plt.figure()
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# DATA SET FOR WEEK 1 - JAN 2016

# %%
mon=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-01-11/summarized_mon.csv')
tue=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-01-11/summarized_tue.csv')
wed=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-01-11/summarized_wed.csv')
thur=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-01-11/summarized_thur.csv')
fri=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-01-11/summarized_fri.csv')
fri
# Out:
#         segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 0     263670743776       38        73.0        68.0         NaN         NaN
# 1     104220335881       28         NaN         NaN         NaN         NaN
# 2     290178745056       43        42.0        38.0        52.0        53.0
# 3      30165704457       31        16.0         NaN         NaN         NaN
# 4     319203328736       43        45.0        59.0        52.0         NaN
# 5     241223081737       33         NaN         NaN         NaN         NaN
# 6      93550026505       25        26.0         NaN         NaN         NaN
# 7     203876998921       30         NaN         NaN         NaN         NaN
# 8     279508435680       45        74.0        89.0        60.0        53.0
# 9     139855142665        8         8.0         NaN         NaN         NaN
# 10    118514523913       49        54.0         NaN         NaN         NaN
# ...

# %% [markdown]
# Analysis on the segment ID with the lowest average speed (complete data of hourly average) and exist in

# %%
mon["segment_id"].value_counts().index
# Out:
# Int64Index([ 63216819977,  98046320393, 321015268064,  93180927753,
#             138512965385, 304808477408, 190119681801, 100663313120,
#              79758901984, 251524039392,
#             ...
#              29897269001,  86503595785, 240216195808, 129822114528,
#              55868399369, 214278872841, 122473693920, 315512341216,
#             138613375712, 330276291296],
#            dtype='int64', length=7569)

# %%
mon.loc[mon["segment_id"] == 80228664032]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 1795  80228664032       25        24.0         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 1795        28.0        23.0        26.0        25.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 1795         21.0         24.0         24.0         19.0         22.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 1795         24.0         25.0         30.0         30.0         34.0
#
# [1 rows x 26 columns]

# %%
tue.loc[tue["segment_id"] == 80228664032]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 1637  80228664032       27        32.0         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 1637         NaN         NaN        29.0        30.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 1637         25.0         27.0         32.0         22.0         20.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 1637         23.0         23.0         29.0         36.0          NaN
#
# [1 rows x 26 columns]

# %%
wed.loc[wed["segment_id"] == 80228664032]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 1637  80228664032       25        30.0        23.0         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 1637         NaN         NaN        29.0        24.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 1637         36.0         27.0         26.0         18.0         21.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 1637         23.0         28.0         25.0         23.0          NaN
#
# [1 rows x 26 columns]

# %%
thur.loc[thur["segment_id"] == 80228664032]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 1641  80228664032       25        27.0         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 1641         NaN         NaN        32.0         NaN     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 1641         17.0         36.0         21.0         28.0         25.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 1641         30.0         28.0         21.0         26.0          NaN
#
# [1 rows x 26 columns]

# %%
fri.loc[fri["segment_id"] == 80228664032]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 1629  80228664032       22        32.0         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 1629         NaN         NaN        28.0        22.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 1629         26.0         20.0          9.0          NaN          NaN
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 1629         13.0         17.0         22.0         23.0         25.0
#
# [1 rows x 26 columns]

# %%
mon_day_avg=mon.values[1795][1]
tue_day_avg=tue.values[1637][1]
wed_day_avg=wed.values[1637][1]
thur_day_avg=thur.values[1641][1]
fri_day_avg=fri.values[1629][1]

# %%
df=pd.Series([mon_day_avg, tue_day_avg, wed_day_avg, thur_day_avg, fri_day_avg], index=['Mon','Tue','Wed','Thur','Fri'])
df
# Out:
# Mon     25.0
# Tue     27.0
# Wed     25.0
# Thur    25.0
# Fri     22.0
# dtype: float64

# %%
# %matplotlib inline
plot_of_week=df.plot.bar(grid=True, figsize=(10,10))
plot_of_week.set_ylabel('Avg Speed (km/h)')
plot_of_week.set_xlabel('Days of Week')

# %% [markdown]
# DATA SET FOR WEEK 2

# %%
mon_1=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-02-08/summarized_mon.csv')
tue_1=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-02-08/summarized_tue.csv')
wed_1=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-02-08/summarized_wed.csv')
thur_1=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-02-08/summarized_thur.csv')
fri_1=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-02-08/summarized_fri.csv')
fri_1
# Out:
#         segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 0      68082212617       38        54.0        35.0         NaN         NaN
# 1      72175853321       39         NaN         NaN         NaN         NaN
# 2      35500859145       30         NaN         NaN         NaN         NaN
# 3     290178745056       46        46.0        24.0        44.0        47.0
# 4      30165704457       37         NaN         NaN         NaN         NaN
# 5     284843590368       35         NaN         NaN         NaN         NaN
# 6     235887927049       74        76.0        53.0         NaN         NaN
# 7      93550026505       53         NaN         NaN         NaN         NaN
# 8     203876998921       39        34.0         NaN         NaN         NaN
# 9     279508435680       53        54.0        79.0        72.0        68.0
# 10    118514523913       57        57.0         NaN        58.0        61.0
# ...

# %%
mon_1.loc[mon_1["segment_id"] == 80228664032]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 1573  80228664032       30        26.0         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 1573         NaN        38.0         NaN        25.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 1573         30.0         33.0         29.0         31.0         30.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 1573         32.0         31.0         31.0         26.0         28.0
#
# [1 rows x 26 columns]

# %%
tue_1.loc[tue_1["segment_id"] == 80228664032]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 1598  80228664032       31        34.0        40.0         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 1598         NaN         NaN        32.0        28.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 1598         32.0         32.0         34.0         34.0         28.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 1598         28.0         30.0         28.0         27.0         35.0
#
# [1 rows x 26 columns]

# %%
wed_1.loc[wed_1["segment_id"] == 80228664032]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 1660  80228664032       31        31.0         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 1660         NaN        30.0        28.0         NaN     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 1660         30.0         27.0         32.0         29.0         42.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 1660         29.0         27.0         30.0         50.0         27.0
#
# [1 rows x 26 columns]

# %%
thur_1.loc[thur_1["segment_id"] == 80228664032]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 1673  80228664032       28        31.0         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 1673         NaN        32.0        26.0         NaN     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 1673         35.0         28.0         25.0         28.0         35.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 1673         28.0         24.0         26.0         26.0         24.0
#
# [1 rows x 26 columns]

# %%
fri_1.loc[fri_1["segment_id"] == 80228664032]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 1658  80228664032       29        24.0         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 1658         NaN         NaN         NaN        31.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 1658         31.0         35.0         34.0         22.0         26.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 1658         29.0         28.0         27.0         26.0         31.0
#
# [1 rows x 26 columns]

# %%
mon_day_avg=mon_1.values[1573][1]
tue_day_avg=tue_1.values[1598][1]
wed_day_avg=wed_1.values[1660][1]
thur_day_avg=thur_1.values[1673][1]
fri_day_avg=fri_1.values[1658][1]

# %%
df_1=pd.Series([mon_day_avg, tue_day_avg, wed_day_avg, thur_day_avg, fri_day_avg], index=['Mon','Tue','Wed','Thur','Fri'])
df_1
# Out:
# Mon     30.0
# Tue     31.0
# Wed     31.0
# Thur    28.0
# Fri     29.0
# dtype: float64

# %%
# %matplotlib inline
plot_of_week=df_1.plot.bar(grid=True, figsize=(10,10))
plot_of_week.set_ylabel('Avg Speed (km/h)')
plot_of_week.set_xlabel('Days of Week')

# %%
both_week= pd.concat([df, df_1], axis=1)

# %%
both_week
# Out:
#          0     1
# Mon   25.0  30.0
# Tue   27.0  31.0
# Wed   25.0  31.0
# Thur  25.0  28.0
# Fri   22.0  29.0

# %%
# %matplotlib inline
both_week.plot.bar(grid=True, figsize=(10,10))
both_week.set_ylabel('Avg Speed (km/h)')
both_week.set_xlabel('Days of Week')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-170-1412b1bf3bdf> in <module>()
#       1 get_ipython().magic('matplotlib inline')
#       2 both_week.plot.bar(grid=True, figsize=(10,10))
# ----> 3 both_week.set_ylabel('Avg Speed (km/h)')
#       4 both_week.set_xlabel('Days of Week')
#
# /Users/hazmanhafiz/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'set_ylabel'

# %%
mon_3=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-01-11/summarized_mon.csv')
tue_3=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-01-11/summarized_tue.csv')
wed_3=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-01-11/summarized_wed.csv')
thur_3=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-01-11/summarized_thur.csv')
fri_3=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-01-11/summarized_fri.csv')

# %%
mon_3.loc[mon_3["segment_id"] == 86637560544]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 2846  86637560544       76        75.0         NaN        73.0         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 2846         NaN         NaN        63.0        70.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 2846         78.0         71.0         74.0         84.0         71.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 2846         67.0         80.0         87.0         69.0         64.0
#
# [1 rows x 26 columns]

# %%
tue_3.loc[tue_3["segment_id"] == 86637560544]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 2613  86637560544       74        66.0         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 2613         NaN         NaN        57.0        67.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 2613         79.0         70.0         76.0         72.0         94.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 2613         73.0         65.0         76.0         95.0          NaN
#
# [1 rows x 26 columns]

# %%
wed_3.loc[wed_3["segment_id"] == 86637560544]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 2617  86637560544       79         NaN         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 2617         NaN         NaN        88.0        82.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 2617         75.0         67.0         65.0         88.0         76.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 2617         96.0         68.0          NaN         76.0         63.0
#
# [1 rows x 26 columns]

# %%
thur_3.loc[thur_3["segment_id"] == 86637560544]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 2631  86637560544       74         NaN         NaN        58.0         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 2631         NaN         NaN        76.0        65.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 2631         70.0         90.0         73.0         76.0         66.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 2631         76.0         65.0         77.0        102.0         73.0
#
# [1 rows x 26 columns]

# %%
fri_3.loc[fri_3["segment_id"] == 86637560544]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 2608  86637560544       75        64.0         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 2608         NaN         NaN        72.0        55.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 2608         77.0         76.0         54.0         69.0         57.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 2608         72.0         74.0        102.0         71.0         71.0
#
# [1 rows x 26 columns]

# %%
mon_day_avg_3=mon_3.values[2846][1]
tue_day_avg_3=tue_3.values[2613][1]
wed_day_avg_3=wed_3.values[2617][1]
thur_day_avg_3=thur_3.values[2631][1]
fri_day_avg_3=fri_3.values[2608][1]

# %%
df_3=pd.Series([mon_day_avg_3, tue_day_avg_3, wed_day_avg_3, thur_day_avg_3, fri_day_avg_3], index=['Mon','Tue','Wed','Thur','Fri'])
df_3
# Out:
# Mon     76.0
# Tue     74.0
# Wed     79.0
# Thur    74.0
# Fri     75.0
# dtype: float64

# %%
mon_4=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-02-08/summarized_mon.csv')
tue_4=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-02-08/summarized_tue.csv')
wed_4=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-02-08/summarized_wed.csv')
thur_4=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-02-08/summarized_thur.csv')
fri_4=pd.read_csv('/Users/hazmanhafiz/Desktop/traffic hackathon/week_2016-02-08/summarized_fri.csv')

# %%
mon_4.loc[mon_4["segment_id"] == 86637560544]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 2523  86637560544       70        57.0         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 2523        63.0        70.0         NaN         NaN     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 2523         68.0         72.0         69.0         80.0         66.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 2523         72.0         87.0         76.0         65.0         59.0
#
# [1 rows x 26 columns]

# %%
tue_4.loc[tue_4["segment_id"] == 86637560544]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 2586  86637560544       77         NaN         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 2586        74.0         NaN         NaN         NaN     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 2586         77.0         68.0         73.0         68.0         85.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 2586         89.0         78.0         66.0         77.0         67.0
#
# [1 rows x 26 columns]

# %%
wed_4.loc[wed_4["segment_id"] == 86637560544]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 2666  86637560544       78        52.0         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 2666         NaN         NaN        77.0        83.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 2666         75.0         82.0         84.0         67.0         84.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 2666         80.0         65.0         80.0         86.0          NaN
#
# [1 rows x 26 columns]

# %%
thur_4.loc[thur_4["segment_id"] == 86637560544]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 2687  86637560544       74        89.0         NaN         NaN         NaN
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 2687         NaN         NaN        81.0         NaN     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 2687         84.0         64.0         90.0         72.0         77.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 2687         71.0         73.0         71.0         81.0         79.0
#
# [1 rows x 26 columns]

# %%
fri_4.loc[fri_4["segment_id"] == 86637560544]
# Out:
#        segment_id  day_avg  hour_0_avg  hour_1_avg  hour_2_avg  hour_3_avg  \
# 2677  86637560544       76        51.0         NaN         NaN        81.0
#
#       hour_4_avg  hour_5_avg  hour_6_avg  hour_7_avg     ...       \
# 2677         NaN         NaN        51.0        97.0     ...
#
#       hour_14_avg  hour_15_avg  hour_16_avg  hour_17_avg  hour_18_avg  \
# 2677         78.0         69.0         82.0         71.0         81.0
#
#       hour_19_avg  hour_20_avg  hour_21_avg  hour_22_avg  hour_23_avg
# 2677         71.0         83.0         64.0         80.0         68.0
#
# [1 rows x 26 columns]

# %%
mon_day_avg_4=mon_4.values[2523][1]
tue_day_avg_4=tue_4.values[2586][1]
wed_day_avg_4=wed_4.values[2666][1]
thur_day_avg_4=thur_4.values[2687][1]
fri_day_avg_4=fri_4.values[2677][1]

# %%
df_4=pd.Series([mon_day_avg_4, tue_day_avg_4, wed_day_avg_4, thur_day_avg_4, fri_day_avg_4], index=['Mon','Tue','Wed','Thur','Fri'])
df_4
# Out:
# Mon     70.0
# Tue     77.0
# Wed     78.0
# Thur    74.0
# Fri     76.0
# dtype: float64

# %%
both_week_1 = pd.concat([df_3, df_4], axis=1)

# %%
both_week_1
# Out:
#          0     1
# Mon   76.0  70.0
# Tue   74.0  77.0
# Wed   79.0  78.0
# Thur  74.0  74.0
# Fri   75.0  76.0

# %%
# %matplotlib inline
both_week_1.plot.bar(grid=True, figsize=(10,10))
both_week_1.set_ylabel('Avg Speed (km/h)')
both_week_1.set_xlabel('Days of Week')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-224-7daf80656dee> in <module>()
#       1 get_ipython().magic('matplotlib inline')
#       2 both_week_1.plot.bar(grid=True, figsize=(10,10))
# ----> 3 both_week_1.set_ylabel('Avg Speed (km/h)')
#       4 both_week_1.set_xlabel('Days of Week')
#
# /Users/hazmanhafiz/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'set_ylabel'

# %%
df_1=pd.Series([mon_day_avg, tue_day_avg, wed_day_avg, thur_day_avg, fri_day_avg], index=['Mon','Tue','Wed','Thur','Fri'])
df_1
# Out:
# Mon     25.0
# Tue     27.0
# Wed     25.0
# Thur    25.0
# Fri     22.0
# dtype: float64

# %%
df_3=pd.Series([mon_day_avg_3, tue_day_avg_3, wed_day_avg_3, thur_day_avg_3, fri_day_avg_3], index=['Mon','Tue','Wed','Thur','Fri'])
df_3
# Out:
# Mon     76.0
# Tue     74.0
# Wed     79.0
# Thur    74.0
# Fri     75.0
# dtype: float64

# %%
both_week_2= pd.concat([df_1, df_3], axis=1)

# %%
both_week_2
# Out:
#          0     1
# Mon   25.0  76.0
# Tue   27.0  74.0
# Wed   25.0  79.0
# Thur  25.0  74.0
# Fri   22.0  75.0

# %%
# %matplotlib inline
both_week_2.plot.bar(grid=True, figsize=(10,10))
both_week_2.set_ylabel('Avg Speed (km/h)')
both_week_2.set_xlabel('Days of Week')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-242-77f0f2029906> in <module>()
#       1 get_ipython().magic('matplotlib inline')
#       2 both_week_2.plot.bar(grid=True, figsize=(10,10))
# ----> 3 both_week_2.set_ylabel('Avg Speed (km/h)')
#       4 both_week_2.set_xlabel('Days of Week')
#
# /Users/hazmanhafiz/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'set_ylabel'
